# %%
# importing pandas library for data manipulation and analysis
import pandas as pd

# %%
# Creating a series of numerical data
data = pd.Series([10, 20, 30, 40, 50])

# %%
# Displaying the series
data
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# Creating a sample dataset of user information (Name, Age, City)
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 22, 35, 28],
    'City': ['New York', 'Los Angeles', 'Chicago', 'San Francisco', 'Miami']
}

# %%
# Creating a dataframe from the sample dataset
df = pd.DataFrame(data)

# %%
# Displaying the dataframe
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2  Charlie   22        Chicago
# 3    David   35  San Francisco
# 4      Eve   28          Miami
