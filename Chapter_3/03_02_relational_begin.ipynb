# %%
# importing the necessary libraries
import pandas as pd # for data manipulation
import sqlalchemy as db # for database connection and operations

# %%
# reading the excel file into a pandas dataframe
customers = pd.read_excel("H+ Sport Customers.xlsx", sheet_name="data")

# %%
# removing duplicate rows from the dataframe
customers.drop_duplicates()
# Out:
#      CustomerID  FirstName  LastName                       Email  \
# 0           100      Carol      Shaw              cshaw0@mlb.com
# 1           101  Elizabeth      Carr           ecarr1@oracle.com
# 2           102     Ernest     Ramos         eramos2@plala.or.jp
# 3           103       Jane    Carter        jcarter3@harvard.edu
# 4           104     Martha    Cooper             mcooper4@go.com
# ..          ...        ...       ...                         ...
# 995        1095      Helen  Castillo     hcastillorn@behance.net
# 996        1096      Peter  Crawford           pcrawfordro@de.vu
# 997        1097     Samuel    Fields  sfieldsrp@reverbnation.com
# 998        1098    Michael  Gonzalez         mgonzalezrq@hud.gov
# 999        1099     Louise  Morrison       lmorrisonrr@nifty.com
#
#              Phone                 Address         City State  Zipcode
# 0    (206)804-8771     8157 Longview Court      Seattle    WA    98121
# ...

# %%
# removing the 'Zipcode' column from the dataframe
customers = customers.drop(columns='Zipcode')

# %%
# displaying the dataframe to verify the changes
customers
# Out:
#      CustomerID  FirstName  LastName                       Email  \
# 0           100      Carol      Shaw              cshaw0@mlb.com
# 1           101  Elizabeth      Carr           ecarr1@oracle.com
# 2           102     Ernest     Ramos         eramos2@plala.or.jp
# 3           103       Jane    Carter        jcarter3@harvard.edu
# 4           104     Martha    Cooper             mcooper4@go.com
# ..          ...        ...       ...                         ...
# 995        1095      Helen  Castillo     hcastillorn@behance.net
# 996        1096      Peter  Crawford           pcrawfordro@de.vu
# 997        1097     Samuel    Fields  sfieldsrp@reverbnation.com
# 998        1098    Michael  Gonzalez         mgonzalezrq@hud.gov
# 999        1099     Louise  Morrison       lmorrisonrr@nifty.com
#
#              Phone                 Address         City State
# 0    (206)804-8771     8157 Longview Court      Seattle    WA
# ...

# %%
# creating a connection to the PostgreSQL database using SQLAlchemy
# using neon.tech as the database provider, and providing the necessary credentials and connection parameters to create our datawarehouse
engine = db.create_engine('postgresql://neondb_owner:npg_yg0pVHBLMQ3G@ep-aged-band-an9m81yf-pooler.c-6.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require')

# %%
# loading the customers dataframe into the PostgreSQL database/ our datawarehouse
customers.to_sql('customers', con=engine, if_exists='replace', index=False)
# Out:
# 1000

# %%
# verifying that the data has been loaded into the database by checking the shape of the dataframe
customers.shape
# Out:
# (1000, 8)
